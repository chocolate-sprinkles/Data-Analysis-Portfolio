# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
cars1 = pd.read_csv("cars1.csv")
cars2 = pd.read_csv("cars2.csv")

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv("cars1.csv")
cars2 = pd.read_csv("cars2.csv")

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
old_col_names = list(cars1.iloc[:,-5:].columns)
cars1 = cars1.rename(columns={old_col_names[0]:"Column 9",old_col_names[1]:"Column 10",old_col_names[2]:"Column 11",old_col_names[3]:"Column 12",old_col_names[4]:"Column 13"})
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(cars1.shape[0])
print(cars2.shape[0])
# Out:
# 198
# 200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = cars1.append(cars2)
cars
# Out:
# C:\Users\choco\AppData\Local\Temp\ipykernel_14232\3958165173.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cars = cars1.append(cars2)
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# ...

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import numpy as np
owners = np.random.randint(15000,73000,size=cars.shape[0])
owners
# Out:
# array([38492, 68465, 16049, 27264, 29580, 40256, 50806, 28433, 19390,
#        49662, 71472, 24685, 22914, 26989, 27036, 27307, 55835, 33025,
#        30761, 15729, 49769, 49473, 43223, 29244, 33408, 45611, 63776,
#        52449, 72098, 43680, 42948, 64657, 18618, 66166, 45056, 15799,
#        58419, 18078, 58117, 55421, 25523, 65819, 42778, 69499, 23055,
#        16924, 32758, 34612, 41199, 24274, 44943, 35213, 43471, 57366,
#        39722, 31576, 25878, 30168, 40194, 43079, 26104, 21000, 35072,
#        64854, 72506, 25547, 35733, 20947, 67307, 32646, 66649, 33589,
#        19485, 22231, 45142, 57742, 65789, 35143, 27521, 33347, 72886,
#        33824, 72212, 31433, 52164, 16513, 69192, 55117, 60541, 41314,
#        24106, 20327, 61086, 36814, 17984, 32362, 35794, 72485, 50640,
#        54302, 39334, 20881, 37858, 42749, 34534, 57828, 72855, 68085,
#        57329, 63222, 30740, 58493, 69418, 15759, 65345, 65213, 39297,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars["owners"] = owners
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
# ...
