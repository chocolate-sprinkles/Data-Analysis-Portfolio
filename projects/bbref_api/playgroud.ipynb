# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2023.html"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find('table', {"id": "per_game-team"})
df = pd.read_html(str(table))[0]
df
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0        Sacramento Kings*  82  241.8  43.6  88.2  0.494  13.8  37.3
# 1    2.0   Golden State Warriors*  82  241.8  43.1  90.2  0.479  16.6  43.2
# 2    3.0           Atlanta Hawks*  82  242.1  44.6  92.4  0.483  10.8  30.5
# 3    4.0          Boston Celtics*  82  243.7  42.2  88.8  0.475  16.0  42.6
# 4    5.0   Oklahoma City Thunder*  82  242.1  43.1  92.6  0.465  12.1  34.1
# 5    6.0      Los Angeles Lakers*  82  242.4  42.9  89.0  0.482  10.8  31.2
# 6    7.0                Utah Jazz  82  241.5  42.5  89.8  0.473  13.3  37.8
# 7    8.0       Memphis Grizzlies*  82  241.2  43.7  92.1  0.475  12.0  34.2
# 8    9.0         Milwaukee Bucks*  82  241.8  42.7  90.4  0.473  14.8  40.3
# 9   10.0           Indiana Pacers  82  240.9  42.0  89.6  0.469  13.6  37.0
# 10  11.0         New York Knicks*  82  243.4  42.0  89.4  0.470  12.6  35.7
# ...

# %%
df.iloc[:30]
# Out:
#       Rk                     Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0        Sacramento Kings*  82  241.8  43.6  88.2  0.494  13.8  37.3
# 1    2.0   Golden State Warriors*  82  241.8  43.1  90.2  0.479  16.6  43.2
# 2    3.0           Atlanta Hawks*  82  242.1  44.6  92.4  0.483  10.8  30.5
# 3    4.0          Boston Celtics*  82  243.7  42.2  88.8  0.475  16.0  42.6
# 4    5.0   Oklahoma City Thunder*  82  242.1  43.1  92.6  0.465  12.1  34.1
# 5    6.0      Los Angeles Lakers*  82  242.4  42.9  89.0  0.482  10.8  31.2
# 6    7.0                Utah Jazz  82  241.5  42.5  89.8  0.473  13.3  37.8
# 7    8.0       Memphis Grizzlies*  82  241.2  43.7  92.1  0.475  12.0  34.2
# 8    9.0         Milwaukee Bucks*  82  241.8  42.7  90.4  0.473  14.8  40.3
# 9   10.0           Indiana Pacers  82  240.9  42.0  89.6  0.469  13.6  37.0
# 10  11.0         New York Knicks*  82  243.4  42.0  89.4  0.470  12.6  35.7
# ...

# %%
df["Team"].apply(lambda x: x.replace("*",""))
# Out:
# 0           Sacramento Kings
# 1      Golden State Warriors
# 2              Atlanta Hawks
# 3             Boston Celtics
# 4      Oklahoma City Thunder
# 5         Los Angeles Lakers
# 6                  Utah Jazz
# 7          Memphis Grizzlies
# 8            Milwaukee Bucks
# 9             Indiana Pacers
# 10           New York Knicks
# 11            Denver Nuggets
# 12    Minnesota Timberwolves
# 13        Philadelphia 76ers
# 14      New Orleans Pelicans
# 15          Dallas Mavericks
# 16              Phoenix Suns
# 17      Los Angeles Clippers
# 18    Portland Trail Blazers
# 19             Brooklyn Nets
# 20        Washington Wizards
# 21             Chicago Bulls
# 22         San Antonio Spurs
# 23           Toronto Raptors
# 24       Cleveland Cavaliers
# 25             Orlando Magic
# 26         Charlotte Hornets
# 27           Houston Rockets
# 28           Detroit Pistons
# 29                Miami Heat
# 30            League Average
# Name: Team, dtype: object

# %%
df.iloc[:,list(range(10,20))]
# Out:
#       2P   2PA    2P%    FT   FTA    FT%   ORB   DRB   TRB   AST
# 0   29.8  50.9  0.586  19.8  25.1  0.790   9.5  32.9  42.5  27.3
# 1   26.5  47.0  0.564  16.0  20.2  0.794  10.5  34.1  44.6  29.8
# 2   33.9  61.8  0.548  18.5  22.6  0.818  11.2  33.2  44.4  25.0
# 3   26.2  46.2  0.567  17.5  21.6  0.812   9.7  35.6  45.3  26.7
# 4   31.0  58.5  0.530  19.2  23.7  0.809  11.4  32.3  43.6  24.4
# 5   32.1  57.8  0.555  20.6  26.6  0.775  10.0  35.7  45.7  25.3
# 6   29.2  52.0  0.560  18.7  23.8  0.786  11.8  34.1  45.9  26.0
# 7   31.7  57.9  0.548  17.5  23.8  0.733  12.0  34.6  46.6  26.0
# 8   27.9  50.1  0.557  16.6  22.4  0.743  11.1  37.5  48.6  25.8
# 9   28.4  52.6  0.540  18.7  23.7  0.790  10.1  31.4  41.5  27.0
# 10  29.4  53.6  0.547  19.4  25.5  0.761  12.6  34.0  46.6  22.9
# 11  31.8  55.2  0.575  16.8  22.4  0.751  10.1  32.9  43.0  28.9
# 12  30.7  54.1  0.568  17.9  23.7  0.755   9.1  32.8  41.9  26.2
# ...

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2023_per_game.html"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find('table', {"id": "per_game_stats"})
df = pd.read_html(str(table))[0]
df
# Out:
#       Rk            Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1  Precious Achiuwa   C  23  TOR  55  12  20.7  3.6   7.3  ...  .702
# 1      2      Steven Adams   C  29  MEM  42  42  27.0  3.7   6.3  ...  .364
# 2      3       Bam Adebayo   C  25  MIA  75  75  34.6  8.0  14.9  ...  .806
# 3      4      Ochai Agbaji  SG  22  UTA  59  22  20.5  2.8   6.5  ...  .812
# 4      5      Santi Aldama  PF  22  MEM  77  20  21.8  3.2   6.8  ...  .750
# ..   ...               ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 700  535    Thaddeus Young  PF  34  TOR  54   9  14.7  2.0   3.7  ...  .692
# 701  536        Trae Young  PG  24  ATL  73  73  34.8  8.2  19.0  ...  .886
# 702  537    Omer Yurtseven   C  24  MIA   9   0   9.2  1.8   3.0  ...  .833
# 703  538       Cody Zeller   C  30  MIA  15   2  14.5  2.5   3.9  ...  .686
# 704  539       Ivica Zubac   C  25  LAC  76  76  28.6  4.3   6.8  ...  .697
#
#      ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# ...

# %%
df.iloc[24]
# Out:
# Rk            Rk
# Player    Player
# Pos          Pos
# Age          Age
# Tm            Tm
# G              G
# GS            GS
# MP            MP
# FG            FG
# FGA          FGA
# FG%          FG%
# 3P            3P
# 3PA          3PA
# 3P%          3P%
# 2P            2P
# 2PA          2PA
# 2P%          2P%
# eFG%        eFG%
# FT            FT
# FTA          FTA
# FT%          FT%
# ORB          ORB
# DRB          DRB
# TRB          TRB
# AST          AST
# STL          STL
# BLK          BLK
# TOV          TOV
# PF            PF
# PTS          PTS
# Name: 24, dtype: object

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2023.html"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
table = soup.find('table', {"id": "advanced-team"})
df = pd.read_html(str(table))[0]
df
# Out:
#    Unnamed: 0_level_0       Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                     Team                Age
# 0                 1.0          Boston Celtics*               27.4
# 1                 2.0     Cleveland Cavaliers*               25.4
# 2                 3.0      Philadelphia 76ers*               28.2
# 3                 4.0       Memphis Grizzlies*               24.4
# 4                 5.0         Milwaukee Bucks*               29.8
# 5                 6.0          Denver Nuggets*               26.6
# 6                 7.0         New York Knicks*               24.5
# 7                 8.0        Sacramento Kings*               25.4
# 8                 9.0            Phoenix Suns*               28.1
# 9                10.0    New Orleans Pelicans*               25.9
# 10               11.0   Golden State Warriors*               27.3
# 11               12.0         Toronto Raptors*               25.8
# ...

# %%
#new_cols = [x[1] for x in df.columns]
df.columns = new_cols
df
# Out:
#       Rk                     Team   Age     W     L  PW  PL    MOV   SOS  \
# 0    1.0          Boston Celtics*  27.4  57.0  25.0  57  25   6.52 -0.15
# 1    2.0     Cleveland Cavaliers*  25.4  51.0  31.0  55  27   5.38 -0.15
# 2    3.0      Philadelphia 76ers*  28.2  54.0  28.0  52  30   4.32  0.06
# 3    4.0       Memphis Grizzlies*  24.4  51.0  31.0  51  31   3.94 -0.34
# 4    5.0         Milwaukee Bucks*  29.8  58.0  24.0  50  32   3.63 -0.02
# 5    6.0          Denver Nuggets*  26.6  53.0  29.0  49  33   3.33 -0.29
# 6    7.0         New York Knicks*  24.5  47.0  35.0  48  34   2.93  0.06
# 7    8.0        Sacramento Kings*  25.4  48.0  34.0  47  35   2.65 -0.35
# 8    9.0            Phoenix Suns*  28.1  45.0  37.0  46  36   2.07  0.01
# 9   10.0    New Orleans Pelicans*  25.9  42.0  40.0  46  36   1.89 -0.26
# 10  11.0   Golden State Warriors*  27.3  44.0  38.0  45  37   1.80 -0.15
# 11  12.0         Toronto Raptors*  25.8  41.0  41.0  45  37   1.48  0.12
# ...

# %%
df.columns[[17,22,27]]
# Out:
# Index(['Unnamed: 17_level_1', 'Unnamed: 22_level_1', 'Unnamed: 27_level_1'], dtype='object')

# %%
df.drop(df.columns[[17,22,27]],axis=1)
# Out:
#       Rk                     Team   Age     W     L  PW  PL    MOV   SOS  \
# 0    1.0          Boston Celtics*  27.4  57.0  25.0  57  25   6.52 -0.15
# 1    2.0     Cleveland Cavaliers*  25.4  51.0  31.0  55  27   5.38 -0.15
# 2    3.0      Philadelphia 76ers*  28.2  54.0  28.0  52  30   4.32  0.06
# 3    4.0       Memphis Grizzlies*  24.4  51.0  31.0  51  31   3.94 -0.34
# 4    5.0         Milwaukee Bucks*  29.8  58.0  24.0  50  32   3.63 -0.02
# 5    6.0          Denver Nuggets*  26.6  53.0  29.0  49  33   3.33 -0.29
# 6    7.0         New York Knicks*  24.5  47.0  35.0  48  34   2.93  0.06
# 7    8.0        Sacramento Kings*  25.4  48.0  34.0  47  35   2.65 -0.35
# 8    9.0            Phoenix Suns*  28.1  45.0  37.0  46  36   2.07  0.01
# 9   10.0    New Orleans Pelicans*  25.9  42.0  40.0  46  36   1.89 -0.26
# 10  11.0   Golden State Warriors*  27.3  44.0  38.0  45  37   1.80 -0.15
# 11  12.0         Toronto Raptors*  25.8  41.0  41.0  45  37   1.48  0.12
# ...
